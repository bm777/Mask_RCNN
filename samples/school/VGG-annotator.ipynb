# %%
import json, os, pandas as pd

# %%
coco = json.load(open(os.path.join("./", "export-coco-lapixdl.json")))

# %%
annotations = []

# %%
zipped = zip(coco["images"], coco["annotations"])

# %%
for i in coco:
    print(i)
# Out:
# type
# images
# categories
# annotations

# %%
len([z for z in zipped])
# Out:
# 5614

# %%
len(coco["annotations"]), len(coco["images"])
# Out:
# (5614, 6554)

# %%
for x in coco["images"]:
    print(x)
# Out:
# {'file_name': '11101303.png', 'height': 1200, 'width': 1600, 'id': 1}
# {'file_name': '11101304.png', 'height': 1200, 'width': 1600, 'id': 2}
# {'file_name': '11101306.png', 'height': 1200, 'width': 1600, 'id': 3}
# {'file_name': '11102313.png', 'height': 1200, 'width': 1600, 'id': 4}
# {'file_name': '11102314.png', 'height': 1200, 'width': 1600, 'id': 5}
# {'file_name': '11102315.png', 'height': 1200, 'width': 1600, 'id': 6}
# {'file_name': '11103305.png', 'height': 1200, 'width': 1600, 'id': 7}
# {'file_name': '11103308.png', 'height': 1200, 'width': 1600, 'id': 8}
# {'file_name': '11103309.png', 'height': 1200, 'width': 1600, 'id': 9}
# {'file_name': '11103310.png', 'height': 1200, 'width': 1600, 'id': 10}
# {'file_name': '11103311.png', 'height': 1200, 'width': 1600, 'id': 11}
# {'file_name': '11103312.png', 'height': 1200, 'width': 1600, 'id': 12}
# {'file_name': '11103313.png', 'height': 1200, 'width': 1600, 'id': 13}
# ...
